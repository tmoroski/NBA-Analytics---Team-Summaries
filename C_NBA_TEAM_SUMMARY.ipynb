# %% [markdown]
# # NBA Team Summary (2019)
#      Source - NBAREFERENCE.COM

# %%
#BACKEND IMPORTS
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import import_ipynb
import B_NBA_Back_End as bk

# %% [markdown]
# ## Oklahoma City Thunder

# %%
bk.summary_plotter(bk.okc_stats_2019)

# %% [markdown]
# ## Miami Heat

# %%
bk.summary_plotter(bk.mia_stats_2019)

# %% [markdown]
# ## San Antonio Spurs

# %%
bk.summary_plotter(bk.sas_stats_2019)

# %% [markdown]
# ## New Orleans Pelicans

# %%
bk.summary_plotter(bk.nop_stats_2019)

# %% [markdown]
# ## Memphis Grizzlies

# %%
bk.summary_plotter(bk.mem_stats_2019)

# %% [markdown]
# ## Brooklyn Nets

# %%
bk.summary_plotter(bk.brk_stats_2019)

# %% [markdown]
# ## New York Knicks

# %%
bk.summary_plotter(bk.nyk_stats_2019)

# %% [markdown]
# ## Orlando Magic

# %%
bk.summary_plotter(bk.orl_stats_2019)

# %% [markdown]
# ## Houston Rockets

# %%
bk.summary_plotter(bk.hou_stats_2019)

# %% [markdown]
# ## Milwauke Bucks

# %%
bk.summary_plotter(bk.mil_stats_2019)

# %% [markdown]
# ## Los Angeles Lakers

# %%
bk.summary_plotter(bk.lal_stats_2019)

# %% [markdown]
# ## Portland Trail Blazers

# %%
bk.summary_plotter(bk.por_stats_2019)

# %% [markdown]
# ## Toronto Raptors

# %%
bk.summary_plotter(bk.okc_stats_2019)

# %% [markdown]
# ## Chicago Bulls

# %%
bk.summary_plotter(bk.tor_stats_2019)

# %% [markdown]
# ## Sacremento Kings

# %%
bk.summary_plotter(bk.sac_stats_2019)

# %% [markdown]
# ## Phoenix Suns

# %%
bk.summary_plotter(bk.pho_stats_2019)

# %% [markdown]
# ## Charlotte Hornets

# %%
bk.summary_plotter(bk.okc_stats_2019)

# %% [markdown]
# ## Dallas Mavericks

# %%
bk.summary_plotter(bk.dal_stats_2019)

# %% [markdown]
# ## Denver Nuggets

# %%
bk.summary_plotter(bk.den_stats_2019)

# %% [markdown]
# ## Minesota Timber Wolves

# %%
bk.summary_plotter(bk.min_stats_2019)

# %% [markdown]
# ## Washington Wizards

# %%
bk.summary_plotter(bk.was_stats_2019)

# %% [markdown]
# ## Atlanta Hawks

# %%
bk.summary_plotter(bk.atl_stats_2019)

# %% [markdown]
# ## Los Angeles Clippers

# %%
bk.summary_plotter(bk.lac_stats_2019)

# %% [markdown]
# ## Indiana Pacers

# %%
bk.summary_plotter(bk.ind_stats_2019)

# %% [markdown]
# ## Utah Jazz

# %%
bk.summary_plotter(bk.uta_stats_2019)

# %% [markdown]
# ## Philadelpiha Sixers

# %%
bk.summary_plotter(bk.phi_stats_2019)

# %% [markdown]
# ## Detroit Pistons

# %%
bk.summary_plotter(bk.det_stats_2019)

# %% [markdown]
# ## Golden State Warriors

# %%
bk.summary_plotter(bk.gsw_stats_2019)

# %% [markdown]
# ## Boston Celtics

# %%
bk.summary_plotter(bk.bos_stats_2019)

# %% [markdown]
# ## Clevland Caveliers

# %%
bk.summary_plotter(bk.cle_stats_2019)
